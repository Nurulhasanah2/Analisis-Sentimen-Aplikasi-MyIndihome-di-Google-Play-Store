# %% [markdown]
# <a href="https://colab.research.google.com/github/Nurulhasanah2/Analisis-Sentimen-Aplikasi-MyIndihome-di-Google-Play-Store/blob/main/Analisis_Sentimen_MyIndihome_di_Playstore.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Crawling Data

# %%
# !pip install google-play-scraper
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 52 kB 1.2 MB/s
# ...
#   Created wheel for google-play-scraper: filename=google_play_scraper-1.1.0-py3-none-any.whl size=24585 sha256=ae720600ecdd37b75e1258c158005a10118088b02adf7a561b992c6ea20fdd53
#   Stored in directory: /root/.cache/pip/wheels/f4/fc/13/fc4c30a74f33bdd956248d2a0f022780fce59250a6a2301ad8
# Successfully built google-play-scraper
# ...

# %%
from google_play_scraper import app
import pandas as pd #untukmembuatdataframe
import numpy as np #untukoperasivektroataumatriks

# %%
from google_play_scraper import Sort, reviews_all
result = reviews_all(
    'com.telkom.indihome.external',
    sleep_milliseconds=0, 
    lang='id', 
    country='id', 
    sort=Sort.NEWEST, 
    count=3000,
)

# %%
df_data = Dpd.ataFrame(np.array(result),columns=['review'])
df_data = df_data.join(pd.DataFrame(df_data.pop('review').tolist()))
df_data.head()
# Out:
#                                             reviewId         userName  \
# 0  gp:AOqpTOHy1r7tL5a5ASZmZsAnsGxu63msbCtLVyixekR...  Muhammad Ridwan
# 1  gp:AOqpTOEglxhxlHn8oyM6X5jKOh-MQWw6KTnOIXLGJPu...   Rizky Patriana
# 2  gp:AOqpTOFCvJe0PcUZZn5IDLGSkA2KLWRYzFwYO8Hqie2...        Lola Lali
# 3  gp:AOqpTOGv1YfMOAKmW-bB3K5UN1EP580Dql9SCcfERuF...    Putri Pratiwi
# 4  gp:AOqpTOFQavxJQNKArZ1XkEmJY_2aCHs0nBLmFJdMEwS...   Hendra Septyan
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a/AATXAJ...
# 1  https://play-lh.googleusercontent.com/a-/AOh14...
# 2  https://play-lh.googleusercontent.com/a/AATXAJ...
# 3  https://play-lh.googleusercontent.com/a-/AOh14...
# 4  https://play-lh.googleusercontent.com/a-/AOh14...
#
#                                              content  score  thumbsUpCount  \
# 0             Aplikasi sangat membantuu.terima kasih      5              0
# ...

# %%
df_data[['userName', 'score','at', 'content']].head()
# Out:
#           userName  score                  at  \
# 0  Muhammad Ridwan      5 2022-05-30 02:41:42
# 1   Rizky Patriana      4 2022-05-30 01:27:59
# 2        Lola Lali      5 2022-05-30 01:27:02
# 3    Putri Pratiwi      5 2022-05-30 01:26:03
# 4   Hendra Septyan      1 2022-05-29 23:44:19
#
#                                              content
# 0             Aplikasi sangat membantuu.terima kasih
# 1                     Tingkatkan terus pelayannya. 👍
# 2  Sebetulnya bagus, cuma mau migrasi paket promo...
# 3  Mempermudah pengecekan tagihan, pemakaian inte...
# 4                                    Aplikasi sampah

# %%
review = df_data[['userName', 'score','at', 'content']]
sorted_df = review.sort_values(by='at', ascending=False) 
sorted_df.head()
# Out:
#           userName  score                  at  \
# 0  Muhammad Ridwan      5 2022-05-30 02:41:42
# 1   Rizky Patriana      4 2022-05-30 01:27:59
# 2        Lola Lali      5 2022-05-30 01:27:02
# 3    Putri Pratiwi      5 2022-05-30 01:26:03
# 4   Hendra Septyan      1 2022-05-29 23:44:19
#
#                                              content
# 0             Aplikasi sangat membantuu.terima kasih
# 1                     Tingkatkan terus pelayannya. 👍
# 2  Sebetulnya bagus, cuma mau migrasi paket promo...
# 3  Mempermudah pengecekan tagihan, pemakaian inte...
# 4                                    Aplikasi sampah

# %%
my_df = sorted_df[['userName', 'score','at', 'content']]

# %%
my_df.head()
# Out:
#           userName  score                  at  \
# 0  Muhammad Ridwan      5 2022-05-30 02:41:42
# 1   Rizky Patriana      4 2022-05-30 01:27:59
# 2        Lola Lali      5 2022-05-30 01:27:02
# 3    Putri Pratiwi      5 2022-05-30 01:26:03
# 4   Hendra Septyan      1 2022-05-29 23:44:19
#
#                                              content
# 0             Aplikasi sangat membantuu.terima kasih
# 1                     Tingkatkan terus pelayannya. 👍
# 2  Sebetulnya bagus, cuma mau migrasi paket promo...
# 3  Mempermudah pengecekan tagihan, pemakaian inte...
# 4                                    Aplikasi sampah

# %%
my_df.to_csv("ReviewMyIndihome.csv", index = False)

# %% [markdown]
# #Analisis Sentimen Regression Logistic

# %%
pip install nltk #untukklasifikasidanpreprocessing
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas as pd 
import re 
import string 
import nltk 
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %% [markdown]
# Menampilkan Dataset

# %%
df = pd.read_csv("/content/ReviewMyIndihome.csv")
df.head()
# Out:
#           userName  score                   at  \
# 0  Muhammad Ridwan      5  2022-05-30 02:41:42
# 1   Rizky Patriana      4  2022-05-30 01:27:59
# 2        Lola Lali      5  2022-05-30 01:27:02
# 3    Putri Pratiwi      5  2022-05-30 01:26:03
# 4   Hendra Septyan      1  2022-05-29 23:44:19
#
#                                              content
# 0             Aplikasi sangat membantuu.terima kasih
# 1                     Tingkatkan terus pelayannya. 👍
# 2  Sebetulnya bagus, cuma mau migrasi paket promo...
# 3  Mempermudah pengecekan tagihan, pemakaian inte...
# 4                                    Aplikasi sampah

# %%
df = df[['content', 'score']]
df.head()
# Out:
#                                              content  score
# 0             Aplikasi sangat membantuu.terima kasih      5
# 1                     Tingkatkan terus pelayannya. 👍      4
# 2  Sebetulnya bagus, cuma mau migrasi paket promo...      5
# 3  Mempermudah pengecekan tagihan, pemakaian inte...      5
# 4                                    Aplikasi sampah      1

# %% [markdown]
# Pelabelan

# %%
df = df[df.score != 3]

pd.set_option('mode.chained_assignment', None)
df["labels"] = df["score"].apply(lambda x: 1 if x < 3  else 0) 
df = df.drop("score",axis=1)

df.head()
# Out:
#                                              content  labels
# 0             Aplikasi sangat membantuu.terima kasih       0
# 1                     Tingkatkan terus pelayannya. 👍       0
# 2  Sebetulnya bagus, cuma mau migrasi paket promo...       0
# 3  Mempermudah pengecekan tagihan, pemakaian inte...       0
# 4                                    Aplikasi sampah       1

# %% [markdown]
# Preprocessing

# %%
from nltk.corpus import stopwords 
from nltk.tokenize import sent_tokenize, word_tokenize

# %%
def pre_process(Review_Text):

    Review_Text = str(Review_Text).lower() #mengecilkanhuruf
    Review_Text = re.sub(r"\d+", "", Review_Text) 
    Review_Text = Review_Text.translate(str.maketrans("","",string.punctuation)) #menghilangkantandabaca
    Review_Text = Review_Text.strip() #menghilangtandastrip
    pisah = Review_Text.split() #menghapuskarakterlain
    tokens = nltk.tokenize.word_tokenize(Review_Text) 
    listStopword =  set(stopwords.words('indonesian'))
 
    removed = []
    for t in tokens:
      if t not in listStopword:
        removed.append(t)

    return Review_Text

df['content'] = df['content'].apply(lambda x:pre_process(x))
df.head()
# Out:
#                                              content  labels
# 0              aplikasi sangat membantuuterima kasih       0
# 1                      tingkatkan terus pelayannya 👍       0
# 2  sebetulnya bagus cuma mau migrasi paket promo ...       0
# 3  mempermudah pengecekan tagihan pemakaian inter...       0
# 4                                    aplikasi sampah       1

# %%
from sklearn.feature_extraction.text import CountVectorizer #mengambilfrekuensikata
cv = CountVectorizer()
cv.fit(df['content'])
X = cv.transform(df['content'])

y = df['labels']

# %% [markdown]
# modelling

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.80)

# %%
for c in [0.01, 0.05, 0.25, 0.5, 1]:
    
    lr = LogisticRegression(C=c)
    lr.fit(X_train, y_train)
    print('Accuracy for C=%s: %s'
         % (c, accuracy_score(y_test, lr.predict(X_test))))
# Out:
# Accuracy for C=0.01: 0.9112514188422247
# Accuracy for C=0.05: 0.922744040862656
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# Accuracy for C=0.25: 0.9299091940976163
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# ...

# %%
predictions = lr.predict(X_test)

# %%
# find accuracy, precision, recall:
from sklearn.metrics import confusion_matrix,classification_report
new = np.asarray(y_test)
confusion_matrix(predictions,y_test)
# Out:
# array([[6134,  476],
#        [ 483, 7003]])

# %%
print(classification_report(predictions,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.93      0.93      6610
#            1       0.94      0.94      0.94      7486
#
#     accuracy                           0.93     14096
#    macro avg       0.93      0.93      0.93     14096
# weighted avg       0.93      0.93      0.93     14096

# %%
from sklearn.metrics import plot_confusion_matrix
plot_confusion_matrix(lr,X_train,y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
